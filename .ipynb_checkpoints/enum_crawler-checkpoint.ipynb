# %% [markdown]
# # ENUM_BANK의 주소를 bloomberg 에서 가져오는 Crawler

# %% [markdown]
# ## 필요한 라이브러리들 인젝션

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import json
import pandas as pd
import re

# %%
import time

# %% [markdown]
# ## 셀레늄에 헤더정보 설정 및 헤더리스 설정

# %%
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.108 Safari/537.36

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('headless')
chrome_options.add_argument('window-size=1920x1080')
chrome_options.add_argument("disable-gpu")
chrome_options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.108 Safari/537.36")
chrome_options.add_argument("lang=ko_KR") # 한국어!
driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver', options=chrome_options)

# %% [markdown]
# ## GIVEN
# ### bing에서 bloomberg company profile + 기업명 검색결과 주소중 첫번째 검색결과 링크를 블룸버그경로로 설정

# %%
df = pd.read_csv('enum_bank_japan - Sheet 1.csv')
df_enum_bank_japan = df
target_list = df_enum_bank_japan.descr
url_origin1 = 'https://www.bing.com/search?q='
bloomberg_company_profile = ' bloomberg company profile'
tmp_url = []
for bank in target_list:
    url1 = url_origin1 + bank + bloomberg_company_profile
    tmp_url.append(url1)
bloomber_url = []
driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver', options=chrome_options)
for url in tmp_url :
    driver.get(url)
    soup = BeautifulSoup(driver.page_source,'html.parser')
    bloomber_url.append(soup.find_all('a')[13].attrs['href'])
driver.close()
bloomber_url

# %%
df_enum_bank_japan
# Out:
#           enum                  key                             descr  \
# 0      JP_SSNB    enum_bank_jp_ssnb       SBI SUMISHIN NET BANK, LTD.
# 1        JP_AB      enum_bank_jp_ab                   AEON BANK, LTD.
# 2       JP_HKB     enum_bank_jp_hkb          THE HOKKAIDO BANK , LTD.
# 3       JP_AMB     enum_bank_jp_amb            THE AOMORI BANK , LTD.
# 4        JP_MB      enum_bank_jp_mb         THE MICHINOKU BANK , LTD.
# 5      JP_AKTB    enum_bank_jp_aktb             THE AKITA BANK , LTD.
# 6      JP_HKTB    enum_bank_jp_hktb            THE HOKUTO BANK , LTD.
# 7      JP_SNIB    enum_bank_jp_snib            THE SHONAI BANK , LTD.
# 8     JP_YMGTB   enum_bank_jp_ymgtb          THE YAMAGATA BANK , LTD.
# 9       JP_BOI     enum_bank_jp_boi          THE BANK OF IWATE , LTD.
# 10     JP_THKB    enum_bank_jp_thkb            THE TOHOKU BANK , LTD.
# 11      JP_SSB     enum_bank_jp_ssb                THE 77 BANK , LTD.
# 12      JP_THB     enum_bank_jp_thb              THE TOHO BANK , LTD.
# 13      JP_GMB     enum_bank_jp_gmb             THE GUNMA BANK , LTD.
# 14    JP_ASKGB   enum_bank_jp_askgb          THE ASHIKAGA BANK , LTD.
# 15      JP_JYB     enum_bank_jp_jyb              THE JOYO BANK , LTD.
# 16     JP_TSKB    enum_bank_jp_tskb               TSUKUBA BANK , LTD.
# 17    JP_MSSNB   enum_bank_jp_mssnb         THE MUSASHINO BANK , LTD.
# 18      JP_CBB     enum_bank_jp_cbb             THE CHIBA BANK , LTD.
# 19       JP_CB      enum_bank_jp_cb       THE CHIBA KOGYO BANK , LTD.
# 20    JP_TKTMB   enum_bank_jp_tktmb       THE TOKYO TOMIN BANK , LTD.
# 21     JP_YKHM    enum_bank_jp_ykgm       THE BANK OF YOKOHAMA , LTD.
# 22      JP_DSB     enum_bank_jp_dsb            THE DAISHI BANK , LTD.
# 23     JP_HKSB    enum_bank_jp_hksb          THE HOKUETSU BANK , LTD.
# 24    JP_YMNSB   enum_bank_jp_ymnsb    THE YAMANASHI CHUO BANK , LTD.
# 25    JP_HCJNB   enum_bank_jp_hcjnb         THE HACHIJUNI BANK , LTD.
# 26    JP_HKRKB   enum_bank_jp_hkrkb          THE HOKURIKU BANK , LTD.
# 27     JP_TYMB    enum_bank_jp_tymb           The BANK OF TOYAMA，LTD．
# 28     JP_HKKB    enum_bank_jp_hkkb           THE HOKKOKU BANK , LTD.
# 29      JP_FKB     enum_bank_jp_fkb             THE FUKUI BANK , LTD.
# ..         ...                  ...                               ...
# 80      JP_TKB     enum_bank_jp_tkb             THE TAIKO BANK , LTD.
# 81     JP_NGNB    enum_bank_jp_ngnb            THE NAGANO BANK , LTD.
# 82     JP_FBOT    enum_bank_jp_fbot   THE FIRST BANK OF TOYAMA , LTD.
# 83     JP_FKHB    enum_bank_jp_fkhb            THE FUKUHO BANK , LTD.
# 84    JP_SZKCB   enum_bank_jp_szkcb      THE SHIZUOKACHUO BANK , LTD.
# 85      JP_ACB     enum_bank_jp_acb             THE AICHI BANK , LTD.
# 86    JP_BONGY   enum_bank_jp_bongy         THE BANK OF NAGOYA , LTD.
# 87     JP_CKYB    enum_bank_jp_ckyb            THE CHUKYO BANK , LTD.
# 88     JP_DASB    enum_bank_jp_dasb            THE DAISAN BANK , LTD.
# 89     JP_KSIB    enum_bank_jp_ksib  KANSAI URBAN BANKING CORPORATION
# 90     JP_TISB    enum_bank_jp_tisb            THE TAISHO BANK , LTD.
# 91     JP_MNTB    enum_bank_jp_mntb            THE MINATO BANK , LTD.
# 92     JP_SMNB    enum_bank_jp_smnb           THE SHIMANE BANK , LTD.
# 93     JP_TMTB    enum_bank_jp_tmtb                TOMATO BANK , LTD.
# 94     JP_MMJB    enum_bank_jp_mmjb                MOMIJI BANK , LTD.
# 95     JP_SIKB    enum_bank_jp_sikb            THE SAIKYO BANK , LTD.
# 96    JP_TKSMB   enum_bank_jp_tksmb         THE TOKUSHIMA BANK , LTD.
# 97     JP_KGWB    enum_bank_jp_kgwb            THE KAGAWA BANK , LTD.
# 98     JP_EIMB    enum_bank_jp_eimb             THE EHIME BANK , LTD.
# 99     JP_BOKC    enum_bank_jp_bokc          THE BANK OF KOCHI , LTD.
# 100     JP_COB     enum_bank_jp_cob      THE FUKUOKA CHUO BANK , LTD.
# 101   JP_SGKEB   enum_bank_jp_sgkeb        THE SAGA KYOEI BANK , LTD.
# 102   JP_BONGS   enum_bank_jp_bongs       THE BANK OF NAGASAKI , LTD.
# 103   JP_KMMTB   enum_bank_jp_kmmtb          THE KUMAMOTO BANK , LTD.
# 104   JP_HOWAB   enum_bank_jp_howab              THE HOWA BANK , LTD.
# 105  JP_MYZKTB  enum_bank_jp_myzktb    THE MIYAZAKI TAIYO BANK , LTD.
# 106  JP_MNMNPB  enum_bank_jp_mnmnpb     THE MINAMI-NIPPON BANK , LTD.
# 107  JP_OKNWKB  enum_bank_jp_oknwkb     THE OKINAWA KAIHO BANK , LTD.
# 108    JP_YCYB    enum_bank_jp_ycyb           THE YACHIYO BANK , LTD.
# 109     JP_JPB     enum_bank_jp_jpb           JAPAN POST BANK CO, LTD
#
#         Country  code  addr  city  url1  url2
# 0    Country.JP    38   NaN   NaN   NaN   NaN
# 1    Country.JP    40   NaN   NaN   NaN   NaN
# 2    Country.JP   116   NaN   NaN   NaN   NaN
# 3    Country.JP   117   NaN   NaN   NaN   NaN
# 4    Country.JP   118   NaN   NaN   NaN   NaN
# 5    Country.JP   119   NaN   NaN   NaN   NaN
# 6    Country.JP   120   NaN   NaN   NaN   NaN
# 7    Country.JP   121   NaN   NaN   NaN   NaN
# 8    Country.JP   122   NaN   NaN   NaN   NaN
# 9    Country.JP   123   NaN   NaN   NaN   NaN
# 10   Country.JP   124   NaN   NaN   NaN   NaN
# 11   Country.JP   125   NaN   NaN   NaN   NaN
# 12   Country.JP   126   NaN   NaN   NaN   NaN
# 13   Country.JP   128   NaN   NaN   NaN   NaN
# 14   Country.JP   129   NaN   NaN   NaN   NaN
# 15   Country.JP   130   NaN   NaN   NaN   NaN
# 16   Country.JP   131   NaN   NaN   NaN   NaN
# 17   Country.JP   133   NaN   NaN   NaN   NaN
# 18   Country.JP   134   NaN   NaN   NaN   NaN
# 19   Country.JP   135   NaN   NaN   NaN   NaN
# 20   Country.JP   137   NaN   NaN   NaN   NaN
# 21   Country.JP   138   NaN   NaN   NaN   NaN
# 22   Country.JP   140   NaN   NaN   NaN   NaN
# 23   Country.JP   141   NaN   NaN   NaN   NaN
# 24   Country.JP   142   NaN   NaN   NaN   NaN
# 25   Country.JP   143   NaN   NaN   NaN   NaN
# 26   Country.JP   144   NaN   NaN   NaN   NaN
# 27   Country.JP   145   NaN   NaN   NaN   NaN
# 28   Country.JP   146   NaN   NaN   NaN   NaN
# 29   Country.JP   147   NaN   NaN   NaN   NaN
# ..          ...   ...   ...   ...   ...   ...
# 80   Country.JP   532   NaN   NaN   NaN   NaN
# 81   Country.JP   533   NaN   NaN   NaN   NaN
# 82   Country.JP   534   NaN   NaN   NaN   NaN
# 83   Country.JP   537   NaN   NaN   NaN   NaN
# 84   Country.JP   538   NaN   NaN   NaN   NaN
# 85   Country.JP   542   NaN   NaN   NaN   NaN
# 86   Country.JP   543   NaN   NaN   NaN   NaN
# 87   Country.JP   544   NaN   NaN   NaN   NaN
# 88   Country.JP   546   NaN   NaN   NaN   NaN
# 89   Country.JP   554   NaN   NaN   NaN   NaN
# 90   Country.JP   555   NaN   NaN   NaN   NaN
# 91   Country.JP   562   NaN   NaN   NaN   NaN
# 92   Country.JP   565   NaN   NaN   NaN   NaN
# 93   Country.JP   566   NaN   NaN   NaN   NaN
# 94   Country.JP   569   NaN   NaN   NaN   NaN
# 95   Country.JP   570   NaN   NaN   NaN   NaN
# 96   Country.JP   572   NaN   NaN   NaN   NaN
# 97   Country.JP   573   NaN   NaN   NaN   NaN
# 98   Country.JP   576   NaN   NaN   NaN   NaN
# 99   Country.JP   578   NaN   NaN   NaN   NaN
# 100  Country.JP   582   NaN   NaN   NaN   NaN
# 101  Country.JP   583   NaN   NaN   NaN   NaN
# 102  Country.JP   585   NaN   NaN   NaN   NaN
# 103  Country.JP   587   NaN   NaN   NaN   NaN
# 104  Country.JP   590   NaN   NaN   NaN   NaN
# 105  Country.JP   591   NaN   NaN   NaN   NaN
# 106  Country.JP   594   NaN   NaN   NaN   NaN
# 107  Country.JP   596   NaN   NaN   NaN   NaN
# 108  Country.JP   597   NaN   NaN   NaN   NaN
# 109  Country.JP  9900   NaN   NaN   NaN   NaN
#
# [110 rows x 9 columns]

# %%
'body > div:nth-child(9) > div > div > div.container.m-t-5.m-b-5 > div > div > ul > li:nth-child(1) > small > span:nth-child(2)'
# Out:
# str

# %%
driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver', options=chrome_options)
driver.get('https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=THE+TOHOKU+BANK')
soup = BeautifulSoup(driver.page_source,'html.parser')

# %%
tmp = soup.select('small span')

# %%
tmp[1].text
# Out:
# '3-1 Uchimaru Morioka 020 0023, '

# %% [markdown]
# ## WHEN1
# ### 해당 기업의 블룸버그 주소에서 address 정보를 가져옴

# %%
addr = []
addr_tmp = []


# driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver')
for idx, url in enumerate(bloomber_url) :
    print(df_enum_bank_japan.descr[idx] , idx, url)
    driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver', options=chrome_options)
    driver.get(url)
    soup = BeautifulSoup(driver.page_source,'html.parser')
    
    try :
        mydivs1 = soup.find("meta", {"itemprop": "address"})['content']
        if (mydivs1 is not None) or (len(mydivs1) != 0) :
            addr.append(mydivs1)
            print(mydivs1)
        else :
            mydivs3 = soup.find_all("div", {"itemprop": "address"})
            if (mydivs3 is not None) or (len(mydivs3) != 0)  :
                addr.append(mydivs3)
                print(mydivs3)
            else :
                mydivs2 = soup.find_all("div", {"class": "infoTableItemValue__e188b0cb"})[4]
                print (mydivs2)
                addr.append(mydivs2)
                
    except Exception as ex: # 에러시 해당 주소 반환
        print(ex)
        addr.append(url)
    driver.close()
    time.sleep(20)
    if idx > 10 : 
        break
# Out:
# SBI SUMISHIN NET BANK, LTD. 0 https://www.bloomberg.com/profiles/companies/0186804D:JP-sbi-sumishin-net-bank-ltd
# 'NoneType' object is not subscriptable
# AEON BANK, LTD. 1 https://www.bloomberg.com/profiles/companies/AEONBZ:JP-aeon-bank-ltd
# 'NoneType' object is not subscriptable
# THE HOKKAIDO BANK , LTD. 2 https://www.bloomberg.com/profiles/companies/8353:JP-hokkaido-bank-ltd/the
# 'NoneType' object is not subscriptable
# THE AOMORI BANK , LTD. 3 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876065
# 'NoneType' object is not subscriptable
# THE MICHINOKU BANK , LTD. 4 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=879235
# 'NoneType' object is not subscriptable
# THE AKITA BANK , LTD. 5 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=876216
# 'NoneType' object is not subscriptable
# THE HOKUTO BANK , LTD. 6 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=5533401
# 'NoneType' object is not subscriptable
# THE SHONAI BANK , LTD. 7 https://www.bloomberg.com/profiles/companies/8347:JP-shonai-bank-ltd/the
# 'NoneType' object is not subscriptable
# THE YAMAGATA BANK , LTD. 8 https://www.bloomberg.com/profile/company/8344:JP
# 'NoneType' object is not subscriptable
# THE BANK OF IWATE , LTD. 9 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=878782
# 'NoneType' object is not subscriptable
# THE TOHOKU BANK , LTD. 10 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=881271
# 'NoneType' object is not subscriptable
# THE 77 BANK , LTD. 11 https://www.bloomberg.com/profiles/people/15413837-kenichi-hotta
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-217-eb3a6da355a0> in <module>
#       7     print(df_enum_bank_japan.descr[idx] , idx, url)
#       8     driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver', options=chrome_options)
# ----> 9     driver.get(url)
#      10     soup = BeautifulSoup(driver.page_source,'html.parser')
#      11
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /anaconda3/lib/python3.7/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# /anaconda3/lib/python3.7/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# /anaconda3/lib/python3.7/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# /anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# /anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=

# %%
descr_list
# Out:
# 0           SBI SUMISHIN NET BANK, LTD.
# 1                       AEON BANK, LTD.
# 2              THE HOKKAIDO BANK , LTD.
# 3                THE AOMORI BANK , LTD.
# 4             THE MICHINOKU BANK , LTD.
# 5                 THE AKITA BANK , LTD.
# 6                THE HOKUTO BANK , LTD.
# 7                THE SHONAI BANK , LTD.
# 8              THE YAMAGATA BANK , LTD.
# 9              THE BANK OF IWATE , LTD.
# 10               THE TOHOKU BANK , LTD.
# 11                   THE 77 BANK , LTD.
# 12                 THE TOHO BANK , LTD.
# 13                THE GUNMA BANK , LTD.
# 14             THE ASHIKAGA BANK , LTD.
# 15                 THE JOYO BANK , LTD.
# 16                  TSUKUBA BANK , LTD.
# 17            THE MUSASHINO BANK , LTD.
# 18                THE CHIBA BANK , LTD.
# 19          THE CHIBA KOGYO BANK , LTD.
# 20          THE TOKYO TOMIN BANK , LTD.
# 21          THE BANK OF YOKOHAMA , LTD.
# 22               THE DAISHI BANK , LTD.
# 23             THE HOKUETSU BANK , LTD.
# 24       THE YAMANASHI CHUO BANK , LTD.
# 25            THE HACHIJUNI BANK , LTD.
# 26             THE HOKURIKU BANK , LTD.
# 27              The BANK OF TOYAMA，LTD．
# 28              THE HOKKOKU BANK , LTD.
# 29                THE FUKUI BANK , LTD.
#                      ...
# 80                THE TAIKO BANK , LTD.
# 81               THE NAGANO BANK , LTD.
# 82      THE FIRST BANK OF TOYAMA , LTD.
# 83               THE FUKUHO BANK , LTD.
# 84         THE SHIZUOKACHUO BANK , LTD.
# 85                THE AICHI BANK , LTD.
# 86            THE BANK OF NAGOYA , LTD.
# 87               THE CHUKYO BANK , LTD.
# 88               THE DAISAN BANK , LTD.
# 89     KANSAI URBAN BANKING CORPORATION
# 90               THE TAISHO BANK , LTD.
# 91               THE MINATO BANK , LTD.
# 92              THE SHIMANE BANK , LTD.
# 93                   TOMATO BANK , LTD.
# 94                   MOMIJI BANK , LTD.
# 95               THE SAIKYO BANK , LTD.
# 96            THE TOKUSHIMA BANK , LTD.
# 97               THE KAGAWA BANK , LTD.
# 98                THE EHIME BANK , LTD.
# 99             THE BANK OF KOCHI , LTD.
# 100        THE FUKUOKA CHUO BANK , LTD.
# 101          THE SAGA KYOEI BANK , LTD.
# 102         THE BANK OF NAGASAKI , LTD.
# 103            THE KUMAMOTO BANK , LTD.
# 104                THE HOWA BANK , LTD.
# 105      THE MIYAZAKI TAIYO BANK , LTD.
# 106       THE MINAMI-NIPPON BANK , LTD.
# 107       THE OKINAWA KAIHO BANK , LTD.
# 108             THE YACHIYO BANK , LTD.
# 109             JAPAN POST BANK CO, LTD
# Name: descr, Length: 110, dtype: object

# %%
addr = []
addr_tmp = []
url = 'https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name='
descr_list = df_enum_bank_japan.descr
# driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver')
for idx, df_data in enumerate(descr_list) :
    print(url + df_data)
# Out:
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=S
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=E
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=E
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=M
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=K
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=K
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=N
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=G
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=O
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=K
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=K
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=A
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=T
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=K
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=T
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=K
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=
# https://transferwise.com/gb/swift-codes/banks?country=0&city=0&name=,
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-226-aa370f168a5d> in <module>
#       5 # driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver')
#       6 for idx, df_data in enumerate(descr_list) :
# ----> 7     print(url + df_data[idx])
#       8
#
# IndexError: string index out of range

# %%
addr = []
driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver', options=chrome_options)
driver.get( 'https://www.bloomberg.com/profiles/companies/AEONBZ:JP-aeon-bank-ltd')
soup = BeautifulSoup(driver.page_source,'html.parser')

mydivs1 = soup.find("meta", {"itemprop": "address"})['content']

if (mydivs1 is not None) or (len(mydivs1) != 0) :
    addr.append(mydivs1)
else : 
    mydivs2 = soup.find_all("div", {"class": "infoTableItemValue__e188b0cb"})[4]
    addr.append(mydivs2)

driver.close()
addr
# Out:
# ['1-6-1 Roppongi, Minato-ku, Tokyo, 106-6018, Japan',
#  'https://www.bloomberg.com/profiles/companies/AEONBZ:JP-aeon-bank-ltd',
#  'https://www.bloomberg.com/profiles/companies/8353:JP-hokkaido-bank-ltd/the',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876065',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=879235']

# %%
addr_tmp[1].prettify
# Out:
# <bound method Tag.prettify of <html><head><script src="https://srv-2019-04-30-06.config.parsely.com/config/bloomberg.com"></script>
# <title>Bloomberg - Are you a robot?</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://assets.bwbx.io/font-service/css/BWHaasGrotesk-55Roman-Web,BWHaasGrotesk-75Bold-Web,BW%20Haas%20Text%20Mono%20A-55%20Roman/font-face.css" rel="stylesheet" type="text/css"/>
# <style rel="stylesheet" type="text/css">
#         html, body, div, span, applet, object, iframe,
#         h1, h2, h3, h4, h5, h6, p, blockquote, pre,
#         a, abbr, acronym, address, big, cite, code,
#         del, dfn, em, img, ins, kbd, q, s, samp,
#         small, strike, strong, sub, sup, tt, var,
#         b, u, i, center,
#         dl, dt, dd, ol, ul, li,
#         fieldset, form, label, legend,
#         table, caption, tbody, tfoot, thead, tr, th, td,
#         article, aside, canvas, details, embed,
#         figure, figcaption, footer, header, hgroup,
#         menu, nav, output, ruby, section, summary,
#         time, mark, audio, video {
#             margin: 0;
#             padding: 0;
#             border: 0;
#             font-size: 100%;
#             font: inherit;
#             vertical-align: baseline;
#         }
#         /* HTML5 display-role reset for older browsers */
#         article, aside, details, figcaption, figure,
#         footer, header, hgroup, menu, nav, section {
#             display: block;
#         }
#         body {
#             line-height: 1;
#         }
#         ol, ul {
#             list-style: none;
#         }
#         blockquote, q {
#             quotes: none;
#         }
#         blockquote:before, blockquote:after,
#         q:before, q:after {
#             content: '';
#             content: none;
#         }
#         table {
#             border-collapse: collapse;
#             border-spacing: 0;
#         }
#
#         * {
#             box-sizing: border-box;
#         }
#
#         body {
#             background-color: #f2f2f2;
#             font-family: "BWHaasGrotesk-55Roman-Web";
#             line-height: 1.2;
#         }
#
#         .header {
#             margin: 0;
#             height: 60px;
#             width: 100%;
#             background-color: black;
#             color: white;
#             overflow-x: hidden;
#         }
#
#         .logo {
#             float: left;
#             margin: 0 20px;
#             height: 60px;
#             width: 140px;
#             background-image: url('data:image/svg+xml;base64,...');
#             background-repeat: no-repeat;
#             background-position: center;
#             font-size: 0;
#         }
#
#         .contact-us {
#             float: right;
#             margin: 0 20px;
#             line-height: 60px;
#             font-family: "BWHaasGrotesk-55Roman-Web";
#             font-size: 14px;
#             color: white;
#             text-decoration: underline;
#         }
#
#         .box {
#             margin: 30px auto;
#             padding: 30px;
#             width: 680px;
#             background-color: white;
#         }
#
#         @media (max-width:760px) {
#             .box {
#                 width: calc(100% - 20px);
#             }
#         }
#
#         .main__heading, .info__heading {
#             font-family: "BWHaasGrotesk-75Bold-Web";
#         }
#
#         .main__heading {
#             font-size: 19px;
#             padding-bottom: 9px;
#         }
#
#         .continue {
#             font-size: 18px;
#         }
#
#         #px-captcha {
#             margin-top: 20px;
#             min-height: 80px;
#         }
#
#         .info {
#             border-top: dotted 1px black;
#             padding-top: 9px;
#         }
#
#         .info + .info {
#             margin-top: 30px;
#         }
#
#         .info__link {
#             color: black;
#             text-decoration: underline;
#         }
#
#         .info__heading {
#             font-size: 16px;
#             line-height: 20px;
#             padding-bottom: 9px;
#         }
#
#         .info__text {
#             padding-bottom: 9px;
#         }
#
#         #block_uuid {
#             display: inline-block;
#             padding: 6px;
#             background-color: #f2f2f2;
#             font-family: "BW Haas Text Mono A-55 Roman";
#             font-size: 14px;
#         }
#
#     </style>
# <script async="" src="https://ml314.com/tag.aspx?303"></script><script async="" id="tb_tfa_script" src="//cdn.taboola.com/libtrc/unip/1194877/tfa.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript"></script><script async="" src="//bat.bing.com/bat.js"></script><script async="" src="https://s.yimg.com/wi/ytc.js"></script><script async="" src="https://a2.adform.net/serving/scripts/trackpoint/async/" type="text/javascript"></script><script async="" id="fence-snippet" src="https://assets.bwbx.io/s3/fence/v4/app.bundle.js"></script><script async="" src="https://a.quora.com/qevents.js"></script><script async="" src="//static.ads-twitter.com/uwt.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript"></script><script async="" src="https://connect.facebook.net/signals/config/114475372488961?v=2.8.47&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script defer="" src="https://www.googletagmanager.com/gtm.js?id=GTM-MNTH5N"></script><script>
#         window._pxAppId = "PX8FCGYgk4";
#         window._pxJsClientSrc = "/8FCGYgk4/init.js";
#         window._pxFirstPartyEnabled = true;
#         window._pxHostUrl = "/8FCGYgk4/xhr";
#         window._pxreCaptchaTheme = "light";
#         window._pxUuid = qs("uuid");
#
#         if(!window._pxUuid) {
#             window.pxInit = function (px) {
#                 px.Events.one("uid", function (uuid) {
#                     if (uuid) {
#                         document.getElementById("block_uuid").innerText = "Block reference ID: " + uuid;
#                     }
#                 });
#             };
#         }
#
#         function qs(name) {
#             var search = window.location.search;
#             var rx = new RegExp("[?&]" + name + "(=([^&#]*)|&|#|$)");
#             var match = rx.exec(search);
#             return match ? decodeURIComponent(match[2].replace(/\+/g, " ")) : "";
#         }
#     </script>
# <script async="" src="/8FCGYgk4/captcha/captcha.js?a=c&amp;m=0"></script>
# <script src="https://www.recaptcha.net/recaptcha/api.js"></script><script async="" src="/8FCGYgk4/init.js"></script><a aria-hidden="true" href="/tosv2.html?_pxhc=1556607364162" rel="nofollow" style="width: 0px; height: 0px; font-size: 0px; line-height: 0;" tabindex="-1" target="_blank"></a><link href="https://assets.bwbx.io" rel="dns-prefetch"/><link href="https://assets.bwbx.io/s3/fence/v4/styles.css" rel="stylesheet"/><link href="https://assets.bwbx.io/font-service/css/BWHaasGrotesk-55Roman-Web,BWHaasGrotesk-75Bold-Web,Bloomberg/font-face.css" rel="stylesheet"/><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1063184170/?random=1556607364254&amp;cv=9&amp;fst=1556607364254&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1050&amp;u_w=1680&amp;u_ah=946&amp;u_aw=1680&amp;u_cd=24&amp;u_his=3&amp;u_tz=540&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;gtm=2wg430&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11e9-b6d1-e9d31555eed3%26url%3DL3Byb2ZpbGVzL2NvbXBhbmllcy9BRU9OQlo6SlAtYWVvbi1iYW5rLWx0ZA%3D%3D&amp;tiba=Bloomberg%20-%20Are%20you%20a%20robot%3F&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://www.googleadservices.com/pagead/conversion/1063184170/?random=1556607364255&amp;cv=9&amp;fst=1556607364255&amp;num=1&amp;value=0&amp;label=6VpQCOnp7YkBEKrO-_oD&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1050&amp;u_w=1680&amp;u_ah=946&amp;u_aw=1680&amp;u_cd=24&amp;u_his=3&amp;u_tz=540&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;gtm=2wg430&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11e9-b6d1-e9d31555eed3%26url%3DL3Byb2ZpbGVzL2NvbXBhbmllcy9BRU9OQlo6SlAtYWVvbi1iYW5rLWx0ZA%3D%3D&amp;tiba=Bloomberg%20-%20Are%20you%20a%20robot%3F&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://www.googleadservices.com/pagead/conversion/759744127/?random=1556607364258&amp;cv=9&amp;fst=1556607364258&amp;num=1&amp;value=0&amp;label=NPt6CL6b_JYBEP-Mo-oC&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1050&amp;u_w=1680&amp;u_ah=946&amp;u_aw=1680&amp;u_cd=24&amp;u_his=3&amp;u_tz=540&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;gtm=2wg430&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11e9-b6d1-e9d31555eed3%26url%3DL3Byb2ZpbGVzL2NvbXBhbmllcy9BRU9OQlo6SlAtYWVvbi1iYW5rLWx0ZA%3D%3D&amp;tiba=Bloomberg%20-%20Are%20you%20a%20robot%3F&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/759744127/?random=1556607364259&amp;cv=9&amp;fst=1556607364259&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;eid=376635471&amp;u_h=1050&amp;u_w=1680&amp;u_ah=946&amp;u_aw=1680&amp;u_cd=24&amp;u_his=3&amp;u_tz=540&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;gtm=2wg430&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11e9-b6d1-e9d31555eed3%26url%3DL3Byb2ZpbGVzL2NvbXBhbmllcy9BRU9OQlo6SlAtYWVvbi1iYW5rLWx0ZA%3D%3D&amp;tiba=Bloomberg%20-%20Are%20you%20a%20robot%3F&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script async="" src="https://a2.adform.net/Serving/TrackPoint/?pm=1118168&amp;ADFdivider=%7C&amp;ord=821899408914&amp;Set1=ko-KR%7Cko-KR%7C1680x1050%7C24&amp;ADFtpmode=2&amp;loc=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11"></script></head>
# <body>
# <header class="header">
# <h1 class="logo">Bloomberg</h1>
# <a class="contact-us" href="/feedback">Need help? Contact us</a>
# </header>
# <section class="box main">
# <h2 class="main__heading">We've detected unusual activity from your computer network</h2>
# <p class="continue">To continue, please click the box below to let us know you're not a robot.</p>
# <div id="px-captcha"><div class="g-recaptcha" data-callback="handleCaptcha" data-sitekey="6Lcj-R8TAAAAABs3FrRPuQhLMbp5QrHsHufzLf7b" data-theme="light"></div></div>
# </section>
# <section class="box">
# <section class="info">
# <h3 class="info__heading">Why did this happen?</h3>
# <p class="info__text">Please make sure your browser supports JavaScript and cookies and that you are not blocking them from loading. For more information you can review our <a class="info__link" href="/notices/tos">Terms of Service</a> and <a class="info__link" href="/notices/tos">Cookie Policy</a>.</p>
# </section>
# <section class="info">
# <h3 class="info__heading">Need Help?</h3>
# <p class="info__text">For inquiries related to this message please <a class="info__link" href="/feedback">contact our support team</a> and provide the reference ID below.</p>
# <div id="block_uuid">Block reference ID: f9c472f0-6b14-11e9-b6d1-e9d31555eed3</div>
# </section>
# </section>
# <script type="text/javascript">
#     document.getElementById("block_uuid").innerText = "Block reference ID: " + window._pxUuid;
#     </script>
# <!-- Google Tag Manager -->
# <script>(function(w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' });
#         var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.defer = true;
#         j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-MNTH5N');</script>
# <!-- End Google Tag Manager -->
# <a aria-hidden="true" href="/tosv2.html?_pxhcb=1556607364162" rel="nofollow" style="width: 0px; height: 0px; font-size: 0px; line-height: 0;" tabindex="-1" target="_blank"></a><script id="" type="text/javascript">(function(a){var b=a.body;a=a.createElement("div");a.innerHTML='\x3cspan id\x3d"parsely-cfg" data-parsely-site\x3d"bloomberg.com"\x3e\x3c/span\x3e';a.id="parsely-root";a.style.display="none";b.appendChild(a)})(document);
# (function(a,b,d){var e=d.location.protocol,f=b+"-"+a,c=d.getElementById(f),g=d.getElementById(b+"-root");b="https:"===e?"d1z2jf7jlzjs58.cloudfront.net":"static."+b+".com";c||(c=d.createElement(a),c.id=f,c.async=!0,c.src=e+"//"+b+"/p.js",g.appendChild(c))})("script","parsely",document);</script><div id="parsely-root" style="display: none;"><span data-parsely-site="bloomberg.com" id="parsely-cfg"></span><script async="" id="parsely-script" src="https://d1z2jf7jlzjs58.cloudfront.net/p.js"></script></div><script id="" src="//action.dstillery.com/orbserv/nsjs?adv=cl1005751&amp;ns=993&amp;nc=BB_DS&amp;ncv=48&amp;dstOrderId=[OrderId]&amp;dstOrderAmount=[OrderAmount]" type="text/javascript"></script><script id="" type="text/javascript">tp=window.tp||[];tp.push(["setAid","IHFDsFInrJ"]);tp.push(["setSandbox",!1]);tp.push(["setUseTinypassAccounts",!1]);tp.push(["setDebug",!1]);tp.push(["setContentSection","undefined"]);tp.push(["setCustomVariable","pageType","undefined"]);tp.push(["setCustomVariable","brand","undefined"]);tp.push(["setCustomVariable","isTerminalBrowser","0"]);tp.push(["setCustomVariable","homepageExperience","undefined"]);
# window.__bloomberg__&&window.__bloomberg__.Pianola?initializePianola():document.addEventListener("pianola:ready",initializePianola);
# function initializePianola(){function c(){d.setState({pianoUrl:"https://buy.tinypass.com",newsletterDataUrl:"https://login.bloomberg.com/api/newsletters/data",registrationUrl:"https://login.bloomberg.com",includeSailthruLink:!0});d.runWorkflow()}function e(){var a="piano-io-script";if(!document.getElementById(a)){var b=document.createElement("script");b.id=a;b.type="text/javascript";b.async=!0;b.src="//cdn.tinypass.com/api/tinypass.min.js";a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(b,
# a)}}var a=window.__bloomberg__.Pianola,d=a.getInstance();a="undefined"!==typeof a.visibilityProxy?a.visibilityProxy(document):null;a?a.proxyLoader(document,c,e):(c(),e());document.removeEventListener("pianola:ready",initializePianola)};</script>
# <script id="" type="text/javascript">(function(){window._pxParam3="true"===google_tag_manager["GTM-MNTH5N"].macro(9)?1:0;window._pxParam4="logged_in"===google_tag_manager["GTM-MNTH5N"].macro(10)?1:0;window._pxParam6=google_tag_manager["GTM-MNTH5N"].macro(11);if(!window._pxAppId){window._pxAppId="PX8FCGYgk4";var b=document.getElementsByTagName("script")[0],a=document.createElement("script");a.async=1;a.src="/8FCGYgk4/init.js";b.parentNode.insertBefore(a,b)}})();</script>
# <noscript>
# <div height="1" style="position:fixed; top:0; left:0; display:none" width="1">
# <img alt="PxPixel" src="/8FCGYgk4/xhr/api/v1/collector/noScript.gif?appId=PX8FCGYgk4"/>
# </div>
# </noscript><script id="" type="text/javascript">(function(a,b,c){var e=decodeURIComponent;var d="||";var g=";;",f="split",h="length",m="indexOf",k="localStorage",l="_ccmdt";a[c]=a[c]||{};a[c].us={};b=a[k]?a[k][l]||"":(b=b.cookie.match(l+"\x3d([^;]*)"))&&b[1]||"";e=e(b)[f](d);b=e[h];if(0<b)for(;b--;)d=e[b][f]("\x3d"),1<d[h]&&(-1<d[1][m](g)?(a[c].us[d[0]]=d[1][f](g),a[c].us[d[0]].pop()):a[c].us[d[0]]=d[1])})(window,document,"_ml");
# function tagWrapper(a){var b=google_tag_manager["GTM-MNTH5N"].macro(12)||"";a=a||"";a=b+"|"+a;"|"===a&&(a=null);var c=window;b="script";c._ml=c._ml||{};c._ml.eid="50066";c._ml.fp=a;c._ml.informer={enable:!0};a=document.getElementsByTagName(b)[0];c=new Date;b=document.createElement(b);b.async=1;b.src="https://ml314.com/tag.aspx?"+c.getDate()+c.getMonth();a.parentNode.insertBefore(b,a)}"undefined"!==typeof ga&&(ga("create",google_tag_manager["GTM-MNTH5N"].macro(13),"auto"),ga(function(a){tagWrapper(a.get("clientId"))}));</script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","114475372488961");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=114475372488961&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">_linkedin_data_partner_id="155577";</script><script id="" type="text/javascript">(function(){var b=document.getElementsByTagName("script")[0],a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://snap.licdn.com/li.lms-analytics/insight.min.js";b.parentNode.insertBefore(a,b)})();</script> <noscript> <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=155577&amp;fmt=gif" style="display:none;" width="1"/> </noscript>
# <script id="" type="text/javascript">!function(d,e,f,a,b,c){d.twq||(a=d.twq=function(){a.exe?a.exe.apply(a,arguments):a.queue.push(arguments)},a.version="1.1",a.queue=[],b=e.createElement(f),b.async=!0,b.src="//static.ads-twitter.com/uwt.js",c=e.getElementsByTagName(f)[0],c.parentNode.insertBefore(b,c))}(window,document,"script");twq("init","ny9oj");twq("track","PageView");</script>
# <img src="//bcp.crwdcntrl.net/map/c=12392/tp=BLPI/tpid=854a40f2-a181-4c69-a650-93a665c54907"/><img src="//bcp.crwdcntrl.net/map/c=12393/tp=BLGA/tpid=UA-11413116-1"/>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","407225039721182");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=407225039721182&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">!function(d,e,f,a,b,c){d.twq||(a=d.twq=function(){a.exe?a.exe.apply(a,arguments):a.queue.push(arguments)},a.version="1.1",a.queue=[],b=e.createElement(f),b.async=!0,b.src="//static.ads-twitter.com/uwt.js",c=e.getElementsByTagName(f)[0],c.parentNode.insertBefore(b,c))}(window,document,"script");twq("init","nyu3t");twq("track","PageView");</script>
# <script id="" type="text/javascript">(function(){function b(){window.google_tag_manager[google_tag_manager["GTM-MNTH5N"].macro(14)].onHtmlSuccess(16);_cc12098.bcp()}var a=document.createElement("script");a.src="//tags.crwdcntrl.net/c/12098/cc.js?ns\x3d_cc12098";a.async="true";a.id="LOTCC_12098";void 0!==a.onreadystatechange?a.onreadystatechange=function(){"loaded"===this.readyState&&(b(),a.onreadystatechange=a=null)}:a.onload=a.onerror=function(c){if("error"===c.type)window.google_tag_manager[google_tag_manager["GTM-MNTH5N"].macro(15)].onHtmlFailure(16);
# b();a.onload=a.onerror=a=null};document.body.appendChild(a)})();</script><script async="" id="LOTCC_12098" src="//tags.crwdcntrl.net/c/12098/cc.js?ns=_cc12098"></script><div style="display: none; visibility: hidden;"><script>function udm_(b){var f="comScore\x3d",a=document,c=a.cookie,u="",q="indexOf",m="substring",r="length",t=2048,d,n="\x26ns_",p="\x26",e,g=window,v=g.encodeURIComponent||escape;if(c[q](f)+1){var h=0;c=c.split(";");for(e=c[r];h<e;h++){var k=c[h][q](f);k+1&&(u=p+unescape(c[h][m](k+f[r])))}}b+=n+"_t\x3d"+ +new Date+n+"c\x3d"+(a.characterSet||a.defaultCharset||"")+u;b[r]>t&&0<b[q](p)&&(d=b[m](0,t-8).lastIndexOf(p),b=(b[m](0,d)+n+"cut\x3d"+v(b[m](d+1)))[m](0,t));a.images?(k=new Image,g.ns_p||(ns_p=k),k.src=
# b):a.write("\x3c","p","\x3e\x3c",'img src\x3d"',b,'" height\x3d"1" width\x3d"1" alt\x3d"*"',"\x3e\x3c","/p","\x3e")}"undefined"==typeof _comscore&&(_comscore=[]);
# (function(){var b="length",f=self,a=f.encodeURIComponent?encodeURIComponent:escape,c=".scorecardresearch.com",u="//app"+c+"/s2e/invite",q=Math,m="script",r="width",t=/c2=(\d*)&/,d,n=function(e){if(e){var g=[];var f=0,h="";for(l in e){var k=typeof e[l];if("string"==k||"number"==k)g[g[b]]=l+"\x3d"+a(e[l]),"c2"==l?h=e[l]:"c1"==l&&(f=1)}if(!(0>=g[b]||""==h)){var d=e.options||{};d.d=d.d||document;if("string"==typeof d.url_append){e=d.url_append.replace(/&/,"\x26").split("\x26");var l=0;for(k=e[b];l<k;l++)h=
# e[l].split("\x3d"),2==h[b]&&(g[g[b]]=h[0]+"\x3d"+a(h[1]))}g=["http","s"==d.d.URL.charAt(4)?"s://sb":"://b",c,"/b?",f?"":"c1\x3d2\x26",g.join("\x26").replace(/&$/,"")];udm_(g.join(""),function(){var a=d;if(!(0>this.src.indexOf("c1\x3d2"))&&a.d.createElement&&(a.force_script_extension||2==this[r]&&this.height>q.round(100*q.random()))){var b=a.d.createElement(m),c=a.d.getElementsByTagName(m)[0];a=[a.script_extension_url||u,"?c2\x3d",this.src.match(t)[1]].join("");c&&(b.src=a,b.async=!0,c.parentNode.insertBefore(b,
# c))}})}}},p=function(a){a=a||_comscore;for(var c=0,d=a[b];c<d;c++)n(a[c]);_comscore=[]};p();(d=f.COMSCORE)?(d.purge=p,d.beacon=n):COMSCORE={purge:p,beacon:n}})();
# (function(){function b(a,b){for(var c=a.toString();c.length<b;)c="0"+c;return c}function f(){var a=new Date;return a.getFullYear()+"-"+b(a.getMonth(),2)+"-"+b(a.getDate(),2)+" "+b(a.getHours(),2)+":"+b(a.getMinutes(),2)+":"+b(a.getSeconds(),2)}var a={name:google_tag_manager["GTM-MNTH5N"].macro(17),bb_localhour:f(),bb_c_type:google_tag_manager["GTM-MNTH5N"].macro(18),bb_cg_3:window.document.title,bb_brand:google_tag_manager["GTM-MNTH5N"].macro(19)||google_tag_manager["GTM-MNTH5N"].macro(20),bb_screensize:window.screen.availWidth+"x"+window.screen.availHeight,bb_viewport:window.innerWidth+
# "x"+window.innerHeight,bb_focus:google_tag_manager["GTM-MNTH5N"].macro(21),bb_refresh:"true"===google_tag_manager["GTM-MNTH5N"].macro(22)?"1":"0",bb_region:google_tag_manager["GTM-MNTH5N"].macro(23)||"US",bb_exp:google_tag_manager["GTM-MNTH5N"].macro(24)||"AMER",c1:2,c2:"3005059",c7:window.document.URL,c8:window.document.title,c9:"",bb_userid:google_tag_manager["GTM-MNTH5N"].macro(25),ns_site:google_tag_manager["GTM-MNTH5N"].macro(28)};google_tag_manager["GTM-MNTH5N"].macro(29)&&(a.bb_cg_2=google_tag_manager["GTM-MNTH5N"].macro(30));google_tag_manager["GTM-MNTH5N"].macro(31)&&(a.bb_groupid=google_tag_manager["GTM-MNTH5N"].macro(32),a.bb_attributor=google_tag_manager["GTM-MNTH5N"].macro(33),
# a.bb_author=google_tag_manager["GTM-MNTH5N"].macro(34),a.bb_pub_d=google_tag_manager["GTM-MNTH5N"].macro(35),a.bb_cg_3=google_tag_manager["GTM-MNTH5N"].macro(36),a.bb_transporter="true"===google_tag_manager["GTM-MNTH5N"].macro(37)?"1":"0",a.bb_slug=google_tag_manager["GTM-MNTH5N"].macro(38),a.bb_topic1=google_tag_manager["GTM-MNTH5N"].macro(39),a.bb_topic2=google_tag_manager["GTM-MNTH5N"].macro(40),a.bb_people=google_tag_manager["GTM-MNTH5N"].macro(41),a.bb_category=google_tag_manager["GTM-MNTH5N"].macro(42),a.legacy_bb_contentage=google_tag_manager["GTM-MNTH5N"].macro(45),google_tag_manager["GTM-MNTH5N"].macro(46)&&(a.bb_topic_opinion=google_tag_manager["GTM-MNTH5N"].macro(47)));COMSCORE.beacon(a)})();</script></div>
# <script id="" type="text/javascript">!function(d,e,f,a,b,c){d.qp||(a=d.qp=function(){a.qp?a.qp.apply(a,arguments):a.queue.push(arguments)},a.queue=[],b=document.createElement(e),b.async=!0,b.src=f,c=document.getElementsByTagName(e)[0],c.parentNode.insertBefore(b,c))}(window,"script","https://a.quora.com/qevents.js");qp("init","7f95fe1a74cb492e8656a1e2ab719ad4");qp("track","ViewContent");</script>
# <noscript><img height="1" src="https://q.quora.com/_/ad/7f95fe1a74cb492e8656a1e2ab719ad4/pixel?tag=ViewContent&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">!function(d,e,f,a,b,c){d.twq||(a=d.twq=function(){a.exe?a.exe.apply(a,arguments):a.queue.push(arguments)},a.version="1.1",a.queue=[],b=e.createElement(f),b.async=!0,b.src="//static.ads-twitter.com/uwt.js",c=e.getElementsByTagName(f)[0],c.parentNode.insertBefore(b,c))}(window,document,"script");twq("init","nz64l");twq("track","PageView");</script>
# <script id="" type="text/javascript">window._fence=function(d,s,l,id,cdn,v){var fs,st,lt,pf,f=window._fence||{};if(d.getElementById(id))return f;fs=d.scripts[0];st=d.createElement(s);lt=d.createElement(l);pf=d.createElement(l);ft=d.createElement(l);pf.rel="dns-prefetch";pf.href=cdn;st.id=id;st.async=true;st.src=cdn+"/s3/fence/"+v+"/app.bundle.js";lt.rel="stylesheet";lt.href=cdn+"/s3/fence/"+v+"/styles.css";ft.rel="stylesheet";ft.href="https://assets.bwbx.io/font-service/css/BWHaasGrotesk-55Roman-Web,BWHaasGrotesk-75Bold-Web,Bloomberg/font-face.css";
# f.q=[];f.nq=[];f.ready=function(cb){f.q.push(cb)};f.notReady=function(cb){f.nq.push(cb)};d.head.appendChild(pf);d.head.appendChild(lt);d.head.appendChild(ft);fs.parentNode.insertBefore(st,fs);return f}(document,"script","link","fence-snippet","https://assets.bwbx.io","v4");
# window._fence.ready(function(){var hostname="www.bloomberg.com";var path="\/tosv2.html";var template="undefined";var isBillionaires=path.indexOf("billionaires/profiles")>-1;if(isBillionaires){var BILLIONAIRES_SELECTORS_TO_SHOW=[".billionaires-header",".bio-header",".billionaires-footer"].map(function(s){return":not("+s+")"}).join("");var BILLIONAIRES_CONFIG={hideContentConfig:{exist:".billionaires-header",hide:".dvz-content"+BILLIONAIRES_SELECTORS_TO_SHOW+", .dvz-v0-ad",hideContainerDirective:"BODY",
# inlineContainerDirective:"NEXT"}};window._fence.enableRender(BILLIONAIRES_CONFIG).addArticle(path)}});</script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","239834876761399");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=239834876761399&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">!function(d,e,f,a,b,c){d.twq||(a=d.twq=function(){a.exe?a.exe.apply(a,arguments):a.queue.push(arguments)},a.version="1.1",a.queue=[],b=e.createElement(f),b.async=!0,b.src="//static.ads-twitter.com/uwt.js",c=e.getElementsByTagName(f)[0],c.parentNode.insertBefore(b,c))}(window,document,"script");twq("init","nzex3");twq("track","PageView");</script>
# <script id="" type="text/javascript">window._adftrack=Array.isArray(window._adftrack)?window._adftrack:window._adftrack?[window._adftrack]:[];window._adftrack.push({pm:1118168});(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://a2.adform.net/serving/scripts/trackpoint/async/";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script>
# <noscript>
# <p style="margin:0;padding:0;border:0;">
# <img alt="" height="1" src="https://a2.adform.net/Serving/TrackPoint/?pm=1118168" width="1"/>
# </p>
# </noscript>
# <script id="" type="text/javascript">(function(d,a,b,f,e){d[e]=d[e]||[];d[e].push({projectId:"10000",properties:{pixelId:"10048438"}});var c=a.createElement(b);c.src=f;c.async=!0;c.onload=c.onreadystatechange=function(){var a=this.readyState,c=d[e];if(!a||"complete"==a||"loaded"==a)try{var b=YAHOO.ywa.I13N.fireBeacon;d[e]=[];d[e].push=function(a){b([a])};b(c)}catch(g){}};a=a.getElementsByTagName(b)[0];b=a.parentNode;b.insertBefore(c,a)})(window,document,"script","https://s.yimg.com/wi/ytc.js","dotq");</script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","1888404258117965");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1888404258117965&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">!function(d,e,f,a,b,c){d.twq||(a=d.twq=function(){a.exe?a.exe.apply(a,arguments):a.queue.push(arguments)},a.version="1.1",a.queue=[],b=e.createElement(f),b.async=!0,b.src="//static.ads-twitter.com/uwt.js",c=e.getElementsByTagName(f)[0],c.parentNode.insertBefore(b,c))}(window,document,"script");twq("init","nyu3t");twq("track","PageView");</script>
# <script id="" type="text/javascript">(function(b){b=b.body;var a=document.createElement("script"),c="//consent.trustarc.com/notice?domain\x3dbloomberg-iabtest.com\x26c\x3dteconsent\x26gtm\x3d1\x26behavior\x3dexpressed";-1!==window.location.search.indexOf("bb_force_cm\x3d1")&&(c+="\x26country\x3dgb");b.appendChild(a);a.type="text/javascript";a.async=!0;a.onload=function(){var a=setInterval(function(){-1!==document.cookie.indexOf("notice_behavior\x3d")&&(clearInterval(a),window.dispatchEvent(new CustomEvent("trustarc-loaded")))},50)};
# a.src=c})(document);</script><script async="" src="//consent.trustarc.com/notice?domain=bloomberg-iabtest.com&amp;c=teconsent&amp;gtm=1&amp;behavior=expressed" type="text/javascript"></script>
# <script id="" type="text/javascript">(function(){function f(){if(!window.frames.__cmpLocator)if(document.body){var a=document.body,b=document.createElement("iframe");b.style="display:none";b.name="__cmpLocator";b.id="__cmpTrustarc";b.src="//trustarc.mgr.consensu.org/get?name\x3dcmpcookie.html";a.appendChild(b)}else setTimeout(f,5)}function g(){var a=arguments;__cmp.a=__cmp.a||[];if(a.length)if("ping"===a[0])a[2]({gdprAppliesGlobally:e,cmpLoaded:!1},!0);else __cmp.a.push([].slice.apply(a));else return __cmp.a}function d(a){try{var b=
# "string"===typeof a.data,c=b?JSON.parse(a.data):a.data;if(c.__cmpCall){var d=c.__cmpCall;window.__cmp(d.command,d.parameter,function(c,f){var e={__cmpReturn:{returnValue:c,success:f,callId:d.callId}};a.source.postMessage(b?JSON.stringify(e):e,"*")})}}catch(l){}}var h=!0,e=!1;f();"function"!==typeof __cmp&&(window.__cmp=g,__cmp.msgHandler=d,__cmp.gdprApplies=h,__cmp.gdprAppliesGlobally=e,window.addEventListener?window.addEventListener("message",d,!1):window.attachEvent("onmessage",d));var k=setInterval(function(){window.__cmp("getConsentData",
# null,function(a,b){if(b){var c=new Date;c.setTime(c.getTime()+31536E6);c="expires\x3d"+c.toUTCString();document.cookie="euconsent\x3d"+a.consentData+"; "+c;clearInterval(k)}})},250)})();</script><iframe id="__cmpTrustarc" name="__cmpLocator" src="//trustarc.mgr.consensu.org/get?name=cmpcookie.html" style="display: none;"></iframe>
# <script id="" type="text/javascript">(function(){var a=document.querySelector("footer.bb-global-footer");if(a)try{var b=a.querySelector(".bb-global-footer__group");var d=b.querySelectorAll(".bb-global-footer__link")[1];var c=document.createElement("div");c.id="teconsent";b.insertBefore(c,d)}catch(e){console.error(e)}})();</script><script id="" type="text/javascript">(function(b,c,e,f,d){b[d]=b[d]||[];var g=function(){var a={ti:"5820275"};a.q=b[d];b[d]=new UET(a);b[d].push("pageLoad")};var a=c.createElement(e);a.src=f;a.async=1;a.onload=a.onreadystatechange=function(){var b=this.readyState;b&&"loaded"!==b&&"complete"!==b||(g(),a.onload=a.onreadystatechange=null)};c=c.getElementsByTagName(e)[0];c.parentNode.insertBefore(a,c)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script><script id="" type="text/javascript">var DATALAYER_OBJECT_NAME="dataLayer",referrerOverride=function(d){var c=window[DATALAYER_OBJECT_NAME]||[];c.push({event:"optimizely-referrer-override","optimizely-referrer":d})},sendCampaignData=function(d,c,h,g,f,k,b,a,e){optimizely&&"function"===typeof optimizely.get&&(g=optimizely.get("data")&&optimizely.get("data").campaigns[c]&&optimizely.get("data").campaigns[c].integrationSettings&&optimizely.get("data").campaigns[c].integrationSettings.google_universal_analytics&&optimizely.get("data").campaigns[c].integrationSettings.google_universal_analytics.universal_analytics_slot)&&
# (d=d?d+"("+c+")":c,h=h.join(","),f=f?f+"("+k+")":h+"("+k+")",b=b?b+"("+a+")":a,e=e?"holdback":"treatment",e=[d,f,b,e].join(":"),b=window[DATALAYER_OBJECT_NAME]||[],b.push({event:"campaign-decided","optimizely-dimension-value":e,"optimizely-dimension-number":g}))},initNewOptimizelyIntegration=function(d,c){var h=!1,g=function(b){var a=window.optimizely.get&&window.optimizely.get("state"),e=a.getRedirectInfo()&&a.getRedirectInfo().referrer;!h&&e&&(d(e),h=!0);a=a.getCampaignStates({isActive:!0});a=a[b];
# e=a.campaignName;if(0<a.audiences.length){var f=a.audiences.map(function(a){return a.name});var g=a.audiences.map(function(a){return a.id})}else f=["everyone_else"],g=[0];var k=a.experiment.name,l=a.experiment.id,m=a.variation.name,n=a.variation.id;c(e,b,f,g,k,l,m,n,a.isInCampaignHoldback)},f=function(){window.optimizely=window.optimizely||[];window.optimizely.push({type:"addListener",filter:{type:"lifecycle",name:"campaignDecided"},handler:function(b){b=b.data.campaign.id;g(b)}})},k=function(){var b=
# window.optimizely.get&&window.optimizely.get("state");if(b){b=b.getCampaignStates({isActive:!0});for(var a in b)g(a)}};k();f()},initOptimizelyIntegration=function(d,c){window.optimizely&&"function"===typeof window.optimizely.get&&initNewOptimizelyIntegration(d,c)};initOptimizelyIntegration(referrerOverride,sendCampaignData);</script><script id="" type="text/javascript">_linkedin_partner_id="403593";window._linkedin_data_partner_ids=window._linkedin_data_partner_ids||[];window._linkedin_data_partner_ids.push(_linkedin_partner_id);</script><script id="" type="text/javascript">(function(){var b=document.getElementsByTagName("script")[0],a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://snap.licdn.com/li.lms-analytics/insight.min.js";b.parentNode.insertBefore(a,b)})();</script>
# <noscript>
# <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=403593&amp;fmt=gif" style="display:none;" width="1"/>
# </noscript>
# <script charset="utf-8" id="" src="//b-code.liadm.com/a-015y.min.js" type="text/javascript"></script><script id="" type="text/javascript">(function(b,e){b.cmd=b.cmd||[];if(e){var a=e.split(":");a=atob(a[1]);a=JSON.parse(a);a=a.ipc_id;for(var f=1,g=73,c=!1,d=0;d<a.length&&!(c=+a[d],c=c>=f&&c<=g);d++);c&&b.cmd.push(function(){"pubads"in b&&b.pubads().setTargeting("ss","on")})}})(window.googletag||{},google_tag_manager["GTM-MNTH5N"].macro(48));</script>
# <script id="" src="https://ads.avocet.io/s?add=5adf6ad75f7614a66abb437a&amp;ty=j" type="text/javascript"></script><script id="" type="text/javascript">function cb(a){dataLayer.push({"Private Browser":a})}var fs=window.requestFileSystem||window.webkitRequestFileSystem;fs||cb(!1);fs(window.TEMPORARY,100,function(){cb(!1)},function(){cb(!0)});</script>
# <script id="" type="text/javascript">window._tfa=window._tfa||[];window._tfa.push({notify:"event",name:"page_view",id:1194877});!function(a,b,d,c){document.getElementById(c)||(a.async=1,a.src=d,a.id=c,b.parentNode.insertBefore(a,b))}(document.createElement("script"),document.getElementsByTagName("script")[0],"//cdn.taboola.com/libtrc/unip/1194877/tfa.js","tb_tfa_script");</script>
# <noscript>
# <img height="0" src="//trc.taboola.com/1194877/log/3/unip?en=page_view" style="display:none" width="0"/>
# </noscript>
# <div id="batBeacon0.29410675734223957" style="width:0px; height:0px; display:none; visibility:hidden;"><img alt="" height="0" id="batBeacon0.7741937451060805" src="https://bat.bing.com/action/0?ti=5820275&amp;Ver=2&amp;mid=07b6b1ad-5023-b49c-9a01-82555de65a84&amp;pi=0&amp;lg=ko-KR&amp;sw=1680&amp;sh=1050&amp;sc=24&amp;tl=Bloomberg%20-%20Are%20you%20a%20robot%3F&amp;p=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11e9-b6d1-e9d31555eed3%26url%3DL3Byb2ZpbGVzL2NvbXBhbmllcy9BRU9OQlo6SlAtYWVvbi1iYW5rLWx0ZA%3D%3D&amp;r=&amp;lt=912&amp;evt=pageLoad&amp;msclkid=N&amp;rn=877558" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/></div><iframe src="//i.liadm.com/s/c/a-015y?s=&amp;cim=&amp;ps=true&amp;ls=true&amp;duid=a-015y--dc23cd42-d4a1-40d2-8664-5a35118df2bd&amp;domainSessionId=&amp;ppid=0&amp;euns=0&amp;ci=0&amp;version=sc-2.2.2&amp;nosync=true&amp;" style="display: none; width: 0px; height: 0px; border: 0px;"></iframe><iframe allowfullscreen="" allowtransparency="true" frameborder="0" hspace="0" id="adformtrackingiframe" marginheight="0" marginwidth="0" mozallowfullscreen="" scrolling="no" src="https://c1.adform.net/imatch/pixels?uid=3357304578656162371&amp;agencyId=5088&amp;advertiserId=232711&amp;src=tp&amp;rnd=833416" style="display:none" vspace="0" webkitallowfullscreen=""></iframe><iframe src="https://bid.g.doubleclick.net/xbbe/pixel?d=KAE" style="display: none;"></iframe><script src="https://px.ads.linkedin.com/collect/?time=1556607369932&amp;pid=403593%2C155577&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11e9-b6d1-e9d31555eed3%26url%3DL3Byb2ZpbGVzL2NvbXBhbmllcy9BRU9OQlo6SlAtYWVvbi1iYW5rLWx0ZA%3D%3D&amp;fmt=js&amp;s=1" type="text/javascript"></script><iframe aria-hidden="true" id="LOTCCFrame_1556607369941" role="presentation" src="https://bcp.crwdcntrl.net/5/c=12098/rand=902464590/pv=y/cmp=1/cmpto=250/int=%23OpR%2380088%23Total%20Site%20Traffic%20%3A%20https%3A%2F%2Fwww.bloomberg.com/rt=ifr" style="border: 0px; width: 0px; height: 0px; display: block;" tabindex="-1" title="empty"></iframe><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=ny9oj&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11e9-b6d1-e9d31555eed3%26url%3DL3Byb2ZpbGVzL2NvbXBhbmllcy9BRU9OQlo6SlAtYWVvbi1iYW5rLWx0ZA%3D%3D" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nyu3t&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11e9-b6d1-e9d31555eed3%26url%3DL3Byb2ZpbGVzL2NvbXBhbmllcy9BRU9OQlo6SlAtYWVvbi1iYW5rLWx0ZA%3D%3D" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nz64l&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.bloomberg.com%2Ftosv2.html%3Fvid%3Df9c9abde-6b14-11e9-bc37-0242ac12000a%26uuid%3Df9c472f0-6b14-11e9-b6d1-e9d31555eed3%26url%3DL3Byb2ZpbGVzL2NvbXBhbmllcy9BRU9OQlo6SlAtYWVvbi1iYW5rLWx0ZA%3D%3D" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nzex3&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=ht ...

# %%
type(addr_tmp[1])
# Out:
# bs4.BeautifulSoup

# %%
addr = []

driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver', options=chrome_options)
for idx, url in enumerate(bloomber_url) :
    print(idx, url)
    addr.append(url)
driver.close()
addr
# Out:
# 0 https://www.bloomberg.com/profiles/companies/0186804D:JP-sbi-sumishin-net-bank-ltd
# 1 https://www.bloomberg.com/profiles/companies/AEONBZ:JP-aeon-bank-ltd
# 2 https://www.bloomberg.com/profiles/companies/8353:JP-hokkaido-bank-ltd/the
# 3 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876065
# 4 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=879235
# 5 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=876216
# 6 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=5533401
# 7 https://www.bloomberg.com/profiles/companies/8347:JP-shonai-bank-ltd/the
# 8 https://www.bloomberg.com/profile/company/8344:JP
# 9 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=878782
# 10 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=881271
# 11 https://www.bloomberg.com/profiles/people/15413837-kenichi-hotta
# 12 https://www.bloomberg.com/profile/company/8346:JP
# 13 https://www.bloomberg.com/profile/company/8334:JP
# 14 https://www.bloomberg.com/profiles/companies/8335:JP-ashikaga-bank-ltd/the
# 15 https://www.bloomberg.com/profiles/companies/8333:JP-joyo-bank-ltd/the
# 16 https://www.bloomberg.com/profile/company/8338:JP
# 17 https://www.bloomberg.com/profiles/companies/8336:JP-musashino-bank-ltd/the
# 18 https://www.bloomberg.com/profile/company/CHBAF:US
# 19 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=877220
# 20 https://www.bloomberg.com/profiles/companies/8339:JP-tokyo-tomin-bank-ltd/the
# 21 https://www.bloomberg.com/profiles/companies/8332:JP-bank-of-yokohama-ltd/the
# 22 https://www.bloomberg.com/profiles/companies/8324:JP-daishi-bank-ltd/the
# 23 https://www.bloomberg.com/profiles/companies/8325:JP-hokuetsu-bank-ltd/the
# 24 https://www.bloomberg.com/profile/company/8360:JP
# 25 https://www.bloomberg.com/profile/company/HACBY:US
# 26 https://www.bloomberg.com/profiles/companies/8357:JP-hokuriku-bank-ltd/the
# 27 https://www.bloomberg.com/profile/company/7184:JP
# 28 https://www.bloomberg.com/profile/company/8363:JP
# 29 https://www.bloomberg.com/profile/company/8362:JP
# 30 https://www.bloomberg.com/profiles/companies/SZCHZ:JP-shizuoka-chuo-bank-ltd
# 31 https://www.bloomberg.com/profile/company/SUGBY:US
# 32 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=878965
# 33 https://www.bloomberg.com/profile/company/8361:JP
# 34 https://www.bloomberg.com/profile/company/8356:JP
# 35 https://www.bloomberg.com/profiles/companies/8374:JP-mie-bank-ltd/the
# 36 https://www.bloomberg.com/profile/company/8368:JP
# 37 https://www.bloomberg.com/profile/company/8366:JP
# 38 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=875356
# 39 https://www.bloomberg.com/profiles/companies/8371:JP-kinki-osaka-bank-ltd/the
# 40 https://www.bloomberg.com/profiles/companies/8375:JP-senshu-ikeda-bank-ltd/the
# 41 https://www.bloomberg.com/profile/company/8367:JP
# 42 https://www.bloomberg.com/profile/company/KIYOF:US
# 43 https://www.bloomberg.com/profiles/companies/TJBLZ:JP-tajima-bank-ltd/the
# 44 https://www.bloomberg.com/profile/company/8383:JP
# 45 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876572
# 46 https://www.bloomberg.com/profile/company/UGO:GR
# 47 https://www.bloomberg.com/profile/company/8379:JP
# 48 https://www.bloomberg.com/profiles/companies/8380:JP-yamaguchi-bank-ltd/the
# 49 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=875305
# 50 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=875404
# 51 https://www.bloomberg.com/profile/company/8385:JP
# 52 https://www.bloomberg.com/profile/company/8387:JP
# 53 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=875410
# 54 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=881186
# 55 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876124
# 56 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=879261
# 57 https://www.bloomberg.com/profiles/companies/8391:JP-shinwa-bank-ltd/the
# 58 https://www.bloomberg.com/profiles/companies/8394:JP-higo-bank-ltd/the
# 59 https://www.bloomberg.com/profile/company/8392:JP
# 60 https://www.bloomberg.com/profile/company/8393:JP
# 61 https://www.bloomberg.com/profiles/companies/8390:JP-kagoshima-bank-ltd/the
# 62 https://www.bloomberg.com/profile/company/8399:JP
# 63 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876881
# 64 https://www.bloomberg.com/profiles/companies/8327:JP-nishi-nippon-city-bank-ltd/the
# 65 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=222697838
# 66 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=3203632
# 67 https://www.bloomberg.com/profile/company/AOZOF:US
# 68 https://www.bloomberg.com/profile/company/8524:JP
# 69 https://www.bloomberg.com/profiles/companies/8520:JP-kirayaka-bank-ltd
# 70 https://www.bloomberg.com/profile/company/8551:JP
# 71 https://www.bloomberg.com/profiles/companies/SDBKZ:JP-sendai-bank-ltd/the
# 72 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=881448
# 73 https://www.bloomberg.com/profile/company/8563:JP
# 74 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876600
# 75 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=879194
# 76 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876210
# 77 https://www.bloomberg.com/profiles/companies/8536:JP-higashi-nippon-bank-ltd/the
# 78 https://www.bloomberg.com/profiles/companies/8384:JP-tokyo-star-bank-ltd/the
# 79 https://www.bloomberg.com/profiles/companies/KNGWZ:JP-kanagawa-bank-ltd/the
# 80 https://www.bloomberg.com/profile/company/8537:JP
# 81 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=4509220
# 82 https://www.bloomberg.com/profile/company/7184:JP
# 83 https://www.bloomberg.com/profiles/companies/FKHBZ:JP-fukuho-bank-ltd/the
# 84 https://www.bloomberg.com/profiles/companies/SZCHZ:JP-shizuoka-chuo-bank-ltd
# 85 https://www.bloomberg.com/profile/company/8527:JP
# 86 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=875331
# 87 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=876186
# 88 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876842
# 89 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=878813
# 90 https://www.bloomberg.com/profiles/companies/TSBLZ:JP-taisho-bank-ltd/the
# 91 https://www.bloomberg.com/profiles/companies/8543:JP-minato-bank-ltd/the
# 92 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=4493189
# 93 https://www.bloomberg.com/profile/company/8542:JP
# 94 https://www.bloomberg.com/profiles/companies/8533:JP-momiji-bank-ltd/the
# 95 https://www.bloomberg.com/profiles/companies/SYBKZ:JP-saikyo-bank-ltd-the
# 96 https://www.bloomberg.com/profiles/companies/8561:JP-tokushima-bank-ltd/the
# 97 https://www.bloomberg.com/profiles/companies/8556:JP-kagawa-bank-ltd/the
# 98 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876063
# 99 https://www.bloomberg.com/profile/company/8416:JP
# 100 https://www.bloomberg.com/profile/company/8540:JP
# 101 https://www.bloomberg.com/profiles/companies/SKBKZ:JP-saga-kyoei-bank-ltd/the
# 102 https://www.bloomberg.com/profiles/companies/BKNSZ:JP-bank-of-nagasaki-ltd/the
# 103 https://www.bloomberg.com/profiles/companies/8553:JP-kumamoto-bank-ltd/the
# 104 https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=5646256
# 105 https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=5646265
# 106 https://www.bloomberg.com/profile/company/8554:JP
# 107 https://www.bloomberg.com/profiles/companies/OKBKZ:JP-okinawa-kaiho-bank-ltd/the
# 108 https://www.bloomberg.com/profiles/companies/8409:JP-kiraboshi-bank-ltd
# 109 https://www.bloomberg.com/profile/company/7182:JP
# ['https://www.bloomberg.com/profiles/companies/0186804D:JP-sbi-sumishin-net-bank-ltd',
#  'https://www.bloomberg.com/profiles/companies/AEONBZ:JP-aeon-bank-ltd',
#  'https://www.bloomberg.com/profiles/companies/8353:JP-hokkaido-bank-ltd/the',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876065',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=879235',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=876216',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=5533401',
#  'https://www.bloomberg.com/profiles/companies/8347:JP-shonai-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/8344:JP',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=878782',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=881271',
#  'https://www.bloomberg.com/profiles/people/15413837-kenichi-hotta',
#  'https://www.bloomberg.com/profile/company/8346:JP',
#  'https://www.bloomberg.com/profile/company/8334:JP',
#  'https://www.bloomberg.com/profiles/companies/8335:JP-ashikaga-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8333:JP-joyo-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/8338:JP',
#  'https://www.bloomberg.com/profiles/companies/8336:JP-musashino-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/CHBAF:US',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=877220',
#  'https://www.bloomberg.com/profiles/companies/8339:JP-tokyo-tomin-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8332:JP-bank-of-yokohama-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8324:JP-daishi-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8325:JP-hokuetsu-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/8360:JP',
#  'https://www.bloomberg.com/profile/company/HACBY:US',
#  'https://www.bloomberg.com/profiles/companies/8357:JP-hokuriku-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/7184:JP',
#  'https://www.bloomberg.com/profile/company/8363:JP',
#  'https://www.bloomberg.com/profile/company/8362:JP',
#  'https://www.bloomberg.com/profiles/companies/SZCHZ:JP-shizuoka-chuo-bank-ltd',
#  'https://www.bloomberg.com/profile/company/SUGBY:US',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=878965',
#  'https://www.bloomberg.com/profile/company/8361:JP',
#  'https://www.bloomberg.com/profile/company/8356:JP',
#  'https://www.bloomberg.com/profiles/companies/8374:JP-mie-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/8368:JP',
#  'https://www.bloomberg.com/profile/company/8366:JP',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=875356',
#  'https://www.bloomberg.com/profiles/companies/8371:JP-kinki-osaka-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8375:JP-senshu-ikeda-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/8367:JP',
#  'https://www.bloomberg.com/profile/company/KIYOF:US',
#  'https://www.bloomberg.com/profiles/companies/TJBLZ:JP-tajima-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/8383:JP',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876572',
#  'https://www.bloomberg.com/profile/company/UGO:GR',
#  'https://www.bloomberg.com/profile/company/8379:JP',
#  'https://www.bloomberg.com/profiles/companies/8380:JP-yamaguchi-bank-ltd/the',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=875305',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=875404',
#  'https://www.bloomberg.com/profile/company/8385:JP',
#  'https://www.bloomberg.com/profile/company/8387:JP',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=875410',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=881186',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876124',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=879261',
#  'https://www.bloomberg.com/profiles/companies/8391:JP-shinwa-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8394:JP-higo-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/8392:JP',
#  'https://www.bloomberg.com/profile/company/8393:JP',
#  'https://www.bloomberg.com/profiles/companies/8390:JP-kagoshima-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/8399:JP',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876881',
#  'https://www.bloomberg.com/profiles/companies/8327:JP-nishi-nippon-city-bank-ltd/the',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=222697838',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=3203632',
#  'https://www.bloomberg.com/profile/company/AOZOF:US',
#  'https://www.bloomberg.com/profile/company/8524:JP',
#  'https://www.bloomberg.com/profiles/companies/8520:JP-kirayaka-bank-ltd',
#  'https://www.bloomberg.com/profile/company/8551:JP',
#  'https://www.bloomberg.com/profiles/companies/SDBKZ:JP-sendai-bank-ltd/the',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=881448',
#  'https://www.bloomberg.com/profile/company/8563:JP',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876600',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=879194',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876210',
#  'https://www.bloomberg.com/profiles/companies/8536:JP-higashi-nippon-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8384:JP-tokyo-star-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/KNGWZ:JP-kanagawa-bank-ltd/the',
#  'https://www.bloomberg.com/profile/company/8537:JP',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=4509220',
#  'https://www.bloomberg.com/profile/company/7184:JP',
#  'https://www.bloomberg.com/profiles/companies/FKHBZ:JP-fukuho-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/SZCHZ:JP-shizuoka-chuo-bank-ltd',
#  'https://www.bloomberg.com/profile/company/8527:JP',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capid=875331',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=876186',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876842',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=878813',
#  'https://www.bloomberg.com/profiles/companies/TSBLZ:JP-taisho-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8543:JP-minato-bank-ltd/the',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=4493189',
#  'https://www.bloomberg.com/profile/company/8542:JP',
#  'https://www.bloomberg.com/profiles/companies/8533:JP-momiji-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/SYBKZ:JP-saikyo-bank-ltd-the',
#  'https://www.bloomberg.com/profiles/companies/8561:JP-tokushima-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8556:JP-kagawa-bank-ltd/the',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=876063',
#  'https://www.bloomberg.com/profile/company/8416:JP',
#  'https://www.bloomberg.com/profile/company/8540:JP',
#  'https://www.bloomberg.com/profiles/companies/SKBKZ:JP-saga-kyoei-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/BKNSZ:JP-bank-of-nagasaki-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8553:JP-kumamoto-bank-ltd/the',
#  'https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=5646256',
#  'https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?capId=5646265',
#  'https://www.bloomberg.com/profile/company/8554:JP',
#  'https://www.bloomberg.com/profiles/companies/OKBKZ:JP-okinawa-kaiho-bank-ltd/the',
#  'https://www.bloomberg.com/profiles/companies/8409:JP-kiraboshi-bank-ltd',
#  'https://www.bloomberg.com/profile/company/7182:JP']

# %% [markdown]
# ## WHEN2
# ### 결과값

# %% [markdown]
# ## 결과값 정규식으로 주소만 가져오기

# %%
pattern = '\[(.*?)\];'
match = re.search(pattern, soup.find_all('script')[15].text)
json.loads('[' + match.group(1) + ']')[3].get('cpRate')
# Out:
# 10.38119757

# %%
addr = []
driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver', options=chrome_options)
driver.get( 'https://www.bloomberg.com/profiles/companies/AEONBZ:JP-aeon-bank-ltd')
soup = BeautifulSoup(driver.page_source,'html.parser')

mydivs1 = soup.find("meta", {"itemprop": "address"})['content']

if (mydivs1 is not None) or (len(mydivs1) != 0) :
    addr.append(mydivs1)
else : 
    mydivs2 = soup.find_all("div", {"class": "infoTableItemValue__e188b0cb"})[4]
    addr.append(mydivs2)

driver.close()
addr
# Out:
# ['1-9-6 Edagawa, Koto-Ku, 135-0051, Japan']

# %%
mydivs1 = soup.find_all("div", {"class": "address"})
if (mydivs1 is None) or (len(mydivs1) == 0) :
    mydivs2 = soup.find_all("div", {"class": "infoTableItemValue__e188b0cb"})[4]
    addr.append(mydivs2)
else : 
    addr.append(mydivs1)

# %%
driver = webdriver.Chrome('/Users/arthur/pywork/chromedriver', options=chrome_options)
driver.get('https://www.bloomberg.com/profiles/companies/AEONBZ:JP-aeon-bank-ltd')
soup = BeautifulSoup(driver.page_source,'html.parser')
driver.close()

# %%
tmp = soup.find("div", {"class": "address"})

# %%
tmp2 = soup.find("meta", {"itemprop": "address"})['content']
tmp2
# Out:
# '1-9-6 Edagawa, Koto-Ku, 135-0051, Japan'

# %%
<meta content="1-9-6 Edagawa, Koto-Ku, 135-0051, Japan" itemprop="address">

# %%
addr = []

# %%
mydivs1 = soup.find("meta", {"itemprop": "address"})['content']
if (mydivs1 is None) or (len(mydivs1) == 0) :
    mydivs2 = soup.find_all("div", {"class": "infoTableItemValue__e188b0cb"})[4]
    addr.append(mydivs2)
else : 
    addr.append(mydivs1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-166-746c7b741a9a> in <module>
#       2 mydivs1 = soup.find_all("div", {"class": "address"})
#       3 if (mydivs1 is None) or (len(mydivs1) == 0) :
# ----> 4     mydivs2 = soup.find_all("div", {"class": "infoTableItemValue__e188b0cb"})[4]
#       5     addr.append(mydivs2)
#       6 else :
#
# IndexError: list index out of range
